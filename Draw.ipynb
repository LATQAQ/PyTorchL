# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data3.csv')

# %%
for i in range(1,92):
    data.age1[i-1] = str(i)
    data.age2[i-1] = str(i)
    data.age3[i-1] = str(i)
    data.age4[i-1] = str(i)
    data.age5[i-1] = str(i)
data = data.dropna(axis=1)
data
# Out:
#     population1  age1  population2  age2  population3  age3  population4  \
# 0      0.901002   1.0     0.966731   1.0     1.040079   1.0     0.841961
# 1      0.905801   2.0     0.985562   2.0     1.031414   2.0     0.820029
# 2      0.907946   3.0     0.995909   3.0     1.008198   3.0     0.795131
# 3      0.922681   4.0     1.011377   4.0     0.987692   4.0     0.783244
# 4      0.940630   5.0     1.020972   5.0     0.962820   5.0     0.775619
# ..          ...   ...          ...   ...          ...   ...          ...
# 86     0.875991  87.0     0.517467  87.0     0.609555  87.0     0.143353
# 87     0.673420  88.0     0.526787  88.0     0.492284  88.0     0.085713
# 88     0.495814  89.0     0.537715  89.0     0.367101  89.0     0.032487
# 89     0.362096  90.0     0.519274  90.0     0.239773  90.0     0.022224
# 90     0.285133  91.0     0.449675  91.0     0.116950  91.0     0.080993
#
#     age4  population5  age5
# 0    1.0     0.965081   1.0
# 1    2.0     0.933337   2.0
# ...

# %%
import random
from matplotlib.ticker import MaxNLocator
plt.figure(figsize=(15,20))

bar_plot = sns.barplot(y = [i for i in range(1,92)], x = [i*random.uniform(0.97, 1.03) for i in data.population1.values], color=sns.color_palette("Paired")[0] , order=data.age1.values[::-1],orient='h', width=1)
bar_plot = sns.barplot(y = [i for i in range(1,92)], x = [-i*random.uniform(0.97, 1.03) for i in data.population1.values], color=sns.color_palette("ch:2.5,-.2,dark=.3")[0],order=[i for i in range(1,92)][::-1],orient='h', width=1)

# plt.rcParams['font.sans-serif'] = ['SimHei']

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = True
bar_plot.set(xlabel="Population", ylabel="Age", title = "年龄结构")
plt.show()

# %%
import random
plt.figure(figsize=(15,20))

bar_plot = sns.barplot(y = [i for i in range(1,92)], x = [i*random.uniform(0.97, 1.03) for i in data.population2.values], color=sns.color_palette("Paired")[0] , order=[i for i in range(1,92)][::-1],orient='h', width=1)
bar_plot = sns.barplot(y = [i for i in range(1,92)], x = [-i*random.uniform(0.97, 1.03) for i in data.population2.values], color=sns.color_palette("ch:2.5,-.2,dark=.3")[0],order=[i for i in range(1,92)][::-1],orient='h', width=1)

# plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = True
bar_plot.set(xlabel="Population", ylabel="Age", title = "年龄结构")
plt.show()

# %%
import random
plt.figure(figsize=(15,20))

bar_plot = sns.barplot(y = data.age3.values, x = [i*random.uniform(0.97, 1.03) for i in data.population3.values], color=sns.color_palette("Paired")[0] , order=data.age3.values[::-1],orient='h', width=1)
bar_plot = sns.barplot(y = data.age3.values, x = [-i*random.uniform(0.97, 1.03) for i in data.population3.values], color=sns.color_palette("ch:2.5,-.2,dark=.3")[0],order=[i for i in range(1,92)][::-1],orient='h', width=1)

# plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = True
bar_plot.set(xlabel="Population", ylabel="Age", title = "年龄结构")
plt.show()

# %%
import random
plt.figure(figsize=(15,20))

bar_plot = sns.barplot(y = data.age4.values, x = [i*random.uniform(0.97, 1.03) for i in data.population4.values], color=sns.color_palette("Paired")[0] , order=data.age4.values[::-1],orient='h', width=1)
bar_plot = sns.barplot(y = data.age4.values, x = [-i*random.uniform(0.97, 1.03) for i in data.population4.values], color=sns.color_palette("ch:2.5,-.2,dark=.3")[0],order=[i for i in range(1,92)][::-1],orient='h', width=1)

# plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = True
bar_plot.set(xlabel="Population", ylabel="Age", title = "年龄结构")
plt.show()

# %%
import random
plt.figure(figsize=(15,20))

bar_plot = sns.barplot(y = data.age5.values, x = [i*random.uniform(0.97, 1.03) for i in data.population5.values], color=sns.color_palette("Paired")[0] , order=data.age5.values[::-1],orient='h', width=1)
bar_plot = sns.barplot(y = data.age5.values, x = [-i*random.uniform(0.97, 1.03) for i in data.population5.values], color=sns.color_palette("ch:2.5,-.2,dark=.3")[0],order=[i for i in range(1,92)][::-1],orient='h', width=1)

# plt.rcParams['font.sans-serif'] = ['SimHei']

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = True
bar_plot.set(xlabel="Population", ylabel="Age", title = "年龄结构")
plt.show()

# %%
data = pd.read_csv('data4.csv')

# %%
data = data.dropna(axis=1)
data
# Out:
#     age  population
# 0     1    0.792581
# 1     2    0.789912
# 2     3    0.782596
# 3     4    0.847680
# 4     5    0.974010
# ..  ...         ...
# 86   87    0.128430
# 87   88    0.089652
# 88   89    0.059460
# 89   90    0.022390
# 90   91    0.014476
#
# [91 rows x 2 columns]

# %%
import random
plt.figure(figsize=(15,20))

bar_plot = sns.barplot(y = data.age.values, x = [i*random.uniform(0.97, 1.03) for i in data.population.values], color=sns.color_palette("Paired")[0] , order=data.age.values[::-1],orient='h', width=1)
bar_plot = sns.barplot(y = data.age.values, x = [-i*random.uniform(0.97, 1.03) for i in data.population.values], color=sns.color_palette("ch:2.5,-.2,dark=.3")[0],order=[i for i in range(1,92)][::-1],orient='h', width=1)

# plt.rcParams['font.sans-serif'] = ['SimHei']

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = True
bar_plot.set(xlabel="Population", ylabel="Age", title = "年龄结构")
plt.show()
